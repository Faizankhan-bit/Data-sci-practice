# %% [markdown]
# # Printing method in python

# %%
print("Hello, World!")
print(10)
# Out:
# Hello, World!
# 10

# %%
print("Age:",25 , "Name:", "Ali")
# Out:
# Age: 25 Name: Ali

# %%
age = 25
name = "Faizan"
print("Name:",name)
print("Age:",age)
# Out:
# Name: Faizan
# Age: 25

# %% [markdown]
# # seperator

# %%
print("2026","14","01",sep="-")
# Out:
# 2026-14-01

# %%
print("Hello", end= " ")
print("World!")
# Out:
# Hello World!

# %%
print("A","B","C", sep="-")
# Out:
# A-B-C

# %% [markdown]
# # f-string

# %%
name = "Faizan"
age = "19"
print("My name is",name,"and my age is",age)
# Out:
# My name is Faizan and my age is 19

# %%
name = "Faizan"
age = "19"
print(f"My name is {name} and my age is {age}")
# Out:
# My name is Faizan and my age is 19

# %% [markdown]
# # str.format

# %%
print("My name is {} and i am {} years old".format("Bob",25))
# Out:
# My name is Bob and i am 25 years old

# %% [markdown]
# # Escape Sequences

# %%
print("Hello\nWorld!")
# Out:
# Hello
# World!

# %%
print("Name\tAge\tCity")
print("Ali\t18\tkarachi")
# Out:
# Name	Age	City
# Ali	18	karachi

# %%
print("My name is %s and i am %d years old." %("charlie",28))
# Out:
# My name is charlie and i am 28 years old.
